# %% [markdown]
# <a href="https://colab.research.google.com/github/KatrinaJMD/IronHack_GitHub/blob/main/%5BPROJECT01%5D_Risk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## PSEUDOCODE

# %% [markdown]
# ```python
# # define a function for the game
# def risk():
#
#     # to generate random numbers, simulating a die roll
#     import random library
#
#     # loop until no units left to either attacker or defender
#     while True:
#
#         # anticipating and handling errors made by the user
#         try:
#
#             # interact with the user to intialize a number of units to play
#             a = ask user no. of units to deploy
#
#             # defining number of units to start the game
#             a = attacker's no. of units
#             d = defender's no. of units
#             x = least no. of units left
#             rounds = count of battles until no units left
#
#             # loop as long as the battle is going on
#             while attacker or defender still have units left:
#
#                 # define a list of number for each team
#                 lst_a = attacker's list of units
#                 lst_d = defender's list of units
#
#                 # counting number of rounds unti the battle is over (no units left either of the team)
#                 rounds = update rounds count for each completed battle
#
#                 # iterate each number from team's list
#                 for each unit in attacker's total unit:
#                     attacker's list.append(simulate die roll by generating random number from 1 to 11)
#                 for each unit in defender's total unit:
#                     defender's list.append(simulate die roll by generating random number from 1 to 11)
#
#                 # sort generated numbers for comparison in the next steps
#                 attacker's list.sort(descending)
#                 defender's list.sort(descending)
#
#                 # showing basic information to the players
#                 print a new line # visual clarity
#                 print ROUND {No. of rounds}
#                 print divider
#                 print attacker's list
#                 print defender's list
#
#                 # track number of dead units for each team
#                 attacker's dead units count = 0
#                 defender's dead units count = 0
#
#                 # for each number in range(list with least units -- because a battle cannot go through if one team has no units left to face the other team)
#                 for each unit in range(x):
#
#                     # if attacker's unit is higher
#                     if attacker[unit] > defender[unit]:
#                         # update dead units for the defender
#                         defender's dead units count + 1
#                     # if defender's unit is higher
#                     elif attacker[unit] < defender[unit]:
#                         # update dead units for the attacker
#                         attacker's dead units count + 1
#                     # if both numbers are equal
#                     if attacker[unit] == defender[unit]:
#                         # advantage to the defender
#                         # lost unit for the attacker
#                         attacker's dead units count + 1
#
#                 # count remaining units for each team
#                 # total no. of units minus dead units
#                 attacker's remaining unit = len(attacker's list) - attacker's dead units count
#                 defender's remaining unit = len(defender's list) - defender's dead units count
#
#                 if attacker's remaining unit >= defender's remaining unit:
#                     x = defender's remaining unit
#                 elif attacker's remaining unit < defender's remaining unit:
#                     x = attacker's remaining unit
#
#                 # update players of lost units and units left
#                 print a new line
#                 print "Attacker lost {loss_a} armies, {a_remain} armies left."
#                 print "Defender lost {loss_d} armies, {d_remain} armies left."
#
#                 # update players of battle results for each face off
#                 print a new line
#                 if attacker's remaining unit < defender's remaining unit:
#                     print "DEFENDER WINS!!!"
#                 elif attacker's remaining unit == defender's remaining unit:
#                     print "DEFENDER WINS!!!"
#                 elif attacker's remaining unit > defender's remaining unit:
#                     print "ATTACKER WINS!!!"
#
#                 print a new line
#
#                 # if one of the teams has no units left,
#                 # battle is over
#                 if attacker's remaining unit == 0:
#                     break
#                 elif defender's remaining unit == 0:
#                     break
#
#                 # update team's count of remaining units left
#                 a = attacker's remaining unit
#                 d = defender's remaining unit
#
#         # if a user typed a mistake
#         except ValueError:
#             # update the user and guide the user on what to do
#             print "Invalid input. Please enter a number."
#             # go back to the beginning of the loop to start again
#             continue
#
#         print a new line
#
#         # if battle is over, ask if the user wants to play again
#         choice = input "Do you want to play again (y/n): "
#
#         # .lower() will ensure that whatever letter case the user types, it won't generate an error
#         # as long as the answer is not "y" or "n"
#         while choice.lower() not in ["y","n"]:
#             # guide the user on waht to do
#             choice = input "Please choose yes (y) or no (n): "
#
#         # if the user chooses yes, start the game again
#         # if the user chooses no
#         if choice.lower() == "n":
#             # tell the user to have a great day
#             print "Okay. Have a great day!"
#             # stop the game
#             break
#
#         print a new line
# ```

# %% [markdown]
# ## Code

# %%
def risk():
    
    import random

    while True:
        try:

            a = int(input("No. of armies to deploy: "))

            a = a
            d = a
            x = a
            rounds = 0

            while (a != 0) or (d != 0):
            
                lst_a = []
                lst_d = []

                rounds += 1      

                for i in range(a):
                    lst_a.append(random.randrange(1, 11))
                for i in range(d):
                    lst_d.append(random.randrange(1, 11))     

                lst_a.sort(reverse=True)
                lst_d.sort(reverse=True)        

                print("\n")
                print(f"ROUND {rounds}")
                print("-" * 38)
                print(f"Attacker = {lst_a}")
                print(f"Defender = {lst_d}")     

                loss_a = 0
                loss_d = 0      


                for i in range(x):
                    if lst_a[i] > lst_d[i]:
                        loss_d += 1
                    elif lst_a[i] < lst_d[i]:
                        loss_a += 1
                    elif lst_a[i] == lst_d[i]:
                        loss_a += 1  


                a_remain = len(lst_a) - loss_a
                d_remain = len(lst_d) - loss_d  

                if a_remain >= d_remain:
                    x = d_remain
                elif a_remain < d_remain:
                    x = a_remain

                print("\n")
                print(f"Attacker lost {loss_a} armies, {a_remain} armies left.")
                print(f"Defender lost {loss_d} armies, {d_remain} armies left.")  

                print("\n")
                if a_remain < d_remain:
                    print("DEFENDER WINS!!!")
                elif a_remain == d_remain:
                    print("DEFENDER WINS!!!")
                elif a_remain > d_remain:
                    print("ATTACKER WINS!!!")

                print("\n")
                if a_remain == 0:
                    # print("DEFENDER WINS!!!")
                    break
                elif d_remain == 0:
                    # print("ATTACKER WINS!!!")
                    break   

                a = a_remain
                d = d_remain

        except ValueError:
            print("Invalid input. Please enter a number.")
            continue

        print("\n")
        choice = input("Do you want to play again (y/n): ")
        while choice.lower() not in ["y","n"]:
            choice = input("Please choose yes (y) or no (n): ")
        if choice.lower() == "n":
            print("Okay. Have a great day!")
            break
        print("\n")

# %% [markdown]
# ## Play

# %%
risk()
# Out:
# ROUND 1
# --------------------------------------
# Attacker = [9, 5, 1, 1]
# Defender = [4, 4, 2, 1]
#
#
# Attacker lost 2 armies, 2 armies left.
# Defender lost 2 armies, 2 armies left.
#
#
# DEFENDER WINS!!!
#
#
#
#
# ROUND 2
# --------------------------------------
# Attacker = [6, 4]
# Defender = [9, 1]
#
#
# Attacker lost 1 armies, 1 armies left.
# Defender lost 1 armies, 1 armies left.
#
#
# DEFENDER WINS!!!
#
#
#
#
# ROUND 3
# --------------------------------------
# Attacker = [7]
# Defender = [2]
#
#
# Attacker lost 0 armies, 1 armies left.
# Defender lost 1 armies, 0 armies left.
#
#
# ATTACKER WINS!!!
#
#
#
#
#
#
#
#
# ROUND 1
# --------------------------------------
# Attacker = [10, 8, 7, 4]
# Defender = [9, 1, 1, 1]
#
#
# Attacker lost 0 armies, 4 armies left.
# Defender lost 4 armies, 0 armies left.
#
#
# ATTACKER WINS!!!
#
#
#
#
# Okay. Have a great day!
